# %%
import pandas as pd

cb_performance_table = pd.read_csv('submission/tables/CB Performance Evaluation.csv',index_col=0)
man_coverage_performance = pd.read_csv('submission/tables/man coverage performance.csv',index_col=0)
man_iso_coverage_performance = pd.read_csv('submission/tables/man iso coverage performance.csv',index_col=0)

# %% [markdown]
# ## Team Level Coverage Performance

# %% [markdown]
# ### Team Coverage Performance by Coverage Scheme

# %% [markdown]
# ![Team Coverage by Scheme](submission/images/CHI-SchemeViz.png)

# %% [markdown]
# ### Team Coverage Performance by Personel Package

# %% [markdown]
# ![Team Coverage by Personal](submission/images/NE-PersonnelViz.png)

# %% [markdown]
# ### Team Coverage Performance by Targeted Coverage

# %% [markdown]
# ![Team Coverage by Targeted Coverage](submission/images/IND-TargetCoverageViz.png)

# %% [markdown]
# ### No Coverage Example (Zone Hole)

# %% [markdown]
# ![Team Coverage by Targeted Coverage](submission/coverage-beat.gif)

# %% [markdown]
# ## Cornerback -  Pass Coverage Performance Evaluation

# %%
cb_performance_table
# Out:
#                    displayName position  snaps  Total Coverage Score  \
# 2557927           Desmond King       CB    432                  73.8
# 2558067        Marlon Humphrey       CB    437                  70.2
# 2555552             Ryan Smith       CB    247                  67.5
# 2555177    Mackensie Alexander       CB    295                  67.4
# 2555539          Xavien Howard       CB    404                  67.4
# 2543681            Kyle Fuller       CB    593                  67.2
# 2495872       Johnathan Joseph       CB    445                  66.5
# 2543811           Pierre Desir       CB    485                  65.9
# 2555175        James Bradberry       CB    538                  65.0
# 2557867      Tre'Davious White       CB    487                  64.0
# 2540197  Nickell Robey-Coleman       CB    340                  63.1
# 2539237            D.J. Hayden       CB    257                  62.0
# 2533062        Stephon Gilmore       CB    588                  61.7
# ...

# %% [markdown]
# ## Cornerback - Man Coverage Performance Evaluation

# %%
man_coverage_performance
# Out:
#                    displayName position  Man Coverage Score  \
# 2556559            Mike Hilton       CB                70.4
# 2539237            D.J. Hayden       CB                67.3
# 2555177    Mackensie Alexander       CB                65.5
# 2558067        Marlon Humphrey       CB                65.2
# 2555539          Xavien Howard       CB                65.0
# 2553353         Darryl Roberts       CB                63.9
# 2553500         Bryce Callahan       CB                63.9
# 2540197  Nickell Robey-Coleman       CB                63.6
# 2559164          Michael Davis       CB                63.5
# 80668        Captain Munnerlyn       CB                63.2
# 2555394           Daryl Worley       CB                35.4
# 2561001            Grant Haley       CB                33.9
# 2543505           Bradley Roby       CB                33.4
# 2539653          Robert Alford       CB                33.3
# 2553536              Troy Hill       CB                31.1
# ...

# %% [markdown]
# ## Cornerback - Isolated Man Coverage Performance Evaluation

# %%
man_iso_coverage_performance
# Out:
#                displayName position  Man Iso Score  Safety Help % Score  \
# 2558067    Marlon Humphrey       CB           69.8                 39.5
# 2555539      Xavien Howard       CB           69.3                 49.9
# 2543681        Kyle Fuller       CB           62.7                 40.9
# 2539338          B.W. Webb       CB           62.3                 35.3
# 2533062    Stephon Gilmore       CB           62.3                 50.1
# 2557867  Tre'Davious White       CB           61.9                 51.5
# 2559164      Michael Davis       CB           60.7                 58.5
# 89756       Jason McCourty       CB           60.3                 40.2
# 2532875    Janoris Jenkins       CB           60.0                 45.8
# 2557840     Chidobe Awuzie       CB           59.3                 60.9
# 2540288        Darius Slay       CB           43.2                 52.0
# 496733           Joe Haden       CB           42.6                 41.0
# ...
