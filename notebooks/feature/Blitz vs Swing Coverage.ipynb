# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import os
import glob
import sys

# %%
from utils import set_basepath

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data/notebooks/feature'

# %%
basepath = set_basepath(steps=2)

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data'

# %%
from src.team import Team
from src.game import Game
from src.play import Play
from src.player import Player
from src.analysis import Analysis, sort_plays_by_result

# %%
analysis = Analysis(basepath=basepath)

# %%
analysis.load_data()

# %%
analysis.load_weeks(1)

# %%
analysis.weeks.keys()
# Out:
# dict_keys(['week1'])

# %%
analysis.process_games()

# %%
analysis.process_teams()
# Out:
# PHI - week1
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from line'] = self.player_tracking['x'] - self.line_of_scrimmage
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance to sideline'] = [min((160/3) - y,y) for y in self.player_tracking['y'].values]
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from center'] = self.player_tracking['y'] - self.play_center
# CLE - week1
# IND - week1
# MIA - week1
# BAL - week1
# NE - week1
# NYG - week1
# NO - week1
# ARI - week1
# CAR - week1
# GB - week1
# DET - week1
# OAK - week1
# CIN - week1
# NYJ - week1
# BUF - week1
# ATL - week1
# PIT - week1
# WAS - week1
# TEN - week1
# TB - week1
# SF - week1
# LA - week1
# DEN - week1
# JAX - week1
# DAL - week1
# CHI - week1
# HOU - week1
# KC - week1
# MIN - week1
# SEA - week1
# LAC - week1

# %%
team = analysis.teams['PHI']

# %%
game = team.games['week1']

# %%
for k, play in enumerate(game.plays):
    print(f'Play: {k+1}')
    print(play)
    play.plot_play(markers='number', show_coverage=True)
# Out:
# Play: 1
# (15:00) M.Ryan pass short right to J.Jones pushed ob at ATL 30 for 10 yards (M.Jenkins).
# Play: 2
# (13:10) M.Ryan pass incomplete short right to C.Ridley (J.Mills, J.Hicks).
# Play: 3
# (13:05) (Shotgun) M.Ryan pass incomplete short left to D.Freeman.
# Play: 4
# (13:01) (Shotgun) M.Ryan pass deep left to J.Jones to PHI 6 for 33 yards (R.Darby).
# Play: 5
# (10:59) (Shotgun) M.Ryan pass incomplete short right to D.Freeman.
# Play: 6
# (9:08) M.Ryan pass incomplete deep left to M.Sanu.
# Play: 7
# (7:01) M.Ryan pass short left to T.Coleman pushed ob at PHI 10 for 26 yards (R.McLeod).
# Play: 8
# (6:19) M.Ryan pass short left to A.Hooper to PHI 7 for 3 yards (N.Gerry). Philadelphia challenged the pass completion ruling, and the play was Upheld. The ruling on the field stands. (Timeout #1.)
# Play: 9
# (5:38) M.Ryan pass incomplete short left.
# Play: 10
# (5:07) (Shotgun) M.Ryan pass incomplete short left to A.Hooper.
# Play: 11
# (:30) M.Ryan pass incomplete short middle to J.Jones (R.Darby).
# Play: 12
# (15:00) (Shotgun) M.Ryan pass short left to D.Freeman to ATL 11 for -7 yards (B.Graham).
# Play: 13
# (5:34) M.Ryan pass deep left to J.Jones pushed ob at ATL 49 for 22 yards (R.Darby) [F.Cox].
# Play: 14
# (4:20) M.Ryan pass short left to M.Sanu to PHI 42 for 8 yards (R.McLeod) [C.Long]. PENALTY on PHI-C.Long, Roughing the Passer, 15 yards, enforced at PHI 42.
# Play: 15
# (3:03) (Shotgun) M.Ryan pass incomplete deep left to M.Sanu.
# Play: 16
# (2:58) (Shotgun) M.Ryan sacked at PHI 34 for -9 yards (J.Hicks).
# Play: 17
# (1:20) (Shotgun) M.Ryan pass short right to J.Jones pushed ob at ATL 24 for 13 yards (J.Mills).
# Play: 18
# (1:15) (Shotgun) M.Ryan pass incomplete deep left to C.Ridley (R.McLeod).
# Play: 19
# (1:10) (Shotgun) M.Ryan pass short right to D.Freeman to ATL 31 for 7 yards (M.Jenkins).
# Play: 20
# (:48) (No Huddle, Shotgun) M.Ryan pass incomplete short left to J.Jones (R.Darby).
# Play: 21
# (11:54) M.Ryan pass short left to J.Jones to ATL 32 for 4 yards (R.Darby).
# Play: 22
# (11:15) M.Ryan pass incomplete deep right to J.Jones (J.Mills) [D.Barnett]. Atlanta challenged the incomplete pass ruling, and the play was Upheld. The ruling on the field stands. (Timeout #1.)
# Play: 23
# (11:04) (Shotgun) M.Ryan pass incomplete short left. PENALTY on ATL-M.Ryan, Intentional Grounding, 12 yards, enforced at ATL 32.
# Play: 24
# (10:57) (Shotgun) M.Ryan pass short middle to J.Jones to ATL 26 for 6 yards (J.Hicks).
# Play: 25
# (3:33) (Shotgun) M.Ryan pass short right to A.Hooper to ATL 40 for 15 yards (J.Mills).
# Play: 26
# (2:48) (Shotgun) M.Ryan pass incomplete short left to J.Jones (R.Darby).
# Play: 27
# (:47) M.Ryan pass incomplete deep middle to J.Jones.
# Play: 28
# (:40) (Shotgun) M.Ryan pass incomplete short middle to E.Saubert (R.McLeod) [F.Cox].
# Play: 29
# (:20) (Shotgun) M.Ryan pass incomplete short right to J.Jones (N.Gerry).
# Play: 30
# (:17) (Shotgun) M.Ryan pass short middle to M.Sanu to PHI 27 for 5 yards (J.Hicks).
# Play: 31
# (13:03) (Shotgun) M.Ryan pass short left intended for J.Jones INTERCEPTED by R.Douglas at PHI 4. R.Douglas ran ob at PHI 4 for no gain.
# Play: 32
# (10:35) M.Ryan pass deep right to J.Jones to PHI 9 for 18 yards (J.Mills) [D.Vaeao].
# Play: 33
# (7:15) (Shotgun) M.Ryan pass short left to M.Sanu to ATL 18 for -5 yards (S.Jones).
# Play: 34
# (6:31) (Shotgun) M.Ryan sacked at ATL 10 for -8 yards (sack split by C.Long and F.Cox). FUMBLES (C.Long) [C.Long], recovered by ATL-A.Mack at ATL 15. A.Mack to ATL 15 for no gain (M.Bennett).
# Play: 35
# (5:45) (Shotgun) M.Ryan pass short left to D.Freeman to ATL 29 for 14 yards (C.Graham).
# Play: 36
# (2:19) (Shotgun) M.Ryan pass short right to A.Hooper to ATL 31 for 6 yards (C.Graham).
# Play: 37
# (2:01) (No Huddle, Shotgun) M.Ryan pass deep middle to J.Jones to PHI 33 for 36 yards (R.McLeod). PHI-R.McLeod was injured during the play.
# Play: 38
# (1:54) (Shotgun) M.Ryan pass incomplete short left to T.Coleman.
# Play: 39
# (1:50) (Shotgun) M.Ryan sacked at PHI 40 for -7 yards (sack split by C.Long and J.Hicks).
# Play: 40
# (1:25) (No Huddle, Shotgun) M.Ryan pass deep left to J.Jones to PHI 22 for 18 yards (R.Darby) [C.Long].
# Play: 41
# (1:18) (Shotgun) M.Ryan pass short right to J.Jones to PHI 13 for 9 yards (J.Mills).
# Play: 42
# (:55) (No Huddle, Shotgun) M.Ryan sacked at PHI 20 for -7 yards (F.Cox).
# Play: 43
# (:29) (No Huddle, Shotgun) M.Ryan pass short left to M.Sanu to PHI 10 for 10 yards (S.Jones).
# Play: 44
# (:24) (Shotgun) M.Ryan pass incomplete short right.
# Play: 45
# (:16) (Shotgun) M.Ryan pass incomplete short middle to J.Jones [M.Bennett].
# Play: 46
# (:11) (Shotgun) M.Ryan pass incomplete short right [F.Cox].
# Play: 47
# (:06) (Shotgun) M.Ryan pass incomplete short right. PENALTY on PHI-J.Hicks, Illegal Contact, 5 yards, enforced at PHI 10 - No Play.
# Play: 48
# (:01) (Shotgun) M.Ryan pass incomplete short left to J.Jones [D.Barnett].

# %%
play = game.plays[2]

# %%
play.plot_play()

# %%
play.target.distance_from_line(play.events['pass_forward'])
# Out:
# -2.780000000000001

# %%
play.backfield_pass
# Out:
# True
