# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import os
import glob
import sys

# %%
from utils import set_basepath

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data/notebooks/feature'

# %%
basepath = set_basepath(steps=2)

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data'

# %%
from src.team import Team
from src.game import Game
from src.play import Play
from src.player import Player
from src.analysis import Analysis, sort_plays_by_result

# %%
analysis = Analysis(basepath=basepath)

# %%
analysis.load_data()

# %%
analysis.load_weeks()

# %%
analysis.weeks.keys()
# Out:
# dict_keys(['week1', 'week2', 'week3', 'week4', 'week5', 'week6', 'week7', 'week8', 'week9', 'week10', 'week11', 'week12', 'week13', 'week14', 'week15', 'week16', 'week17'])

# %%
analysis.process_games()

# %%
analysis.process_teams()
# Out:
# PHI - week1
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from line'] = self.player_tracking['x'] - self.line_of_scrimmage
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance to sideline'] = [min((160/3) - y,y) for y in self.player_tracking['y'].values]
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from center'] = self.player_tracking['y'] - self.play_center
# PHI - week2
# PHI - week3
# PHI - week4
# PHI - week5
# PHI - week6
# PHI - week7
# PHI - week8
# PHI - week9
# PHI - week10
# PHI - week11
# PHI - week12
# PHI - week13
# PHI - week14
# PHI - week15
# PHI - week16
# PHI - week17
# CLE - week1
# CLE - week2
# CLE - week3
# CLE - week4
# CLE - week5
# CLE - week6
# CLE - week7
# CLE - week8
# CLE - week9
# CLE - week10
# CLE - week11
# CLE - week12
# CLE - week13
# CLE - week14
# CLE - week15
# CLE - week16
# CLE - week17
# IND - week1
# IND - week2
# IND - week3
# IND - week4
# IND - week5
# IND - week6
# IND - week7
# IND - week8
# IND - week9
# IND - week10
# IND - week11
# IND - week12
# IND - week13
# IND - week14
# IND - week15
# IND - week16
# IND - week17
# Play Error
# Game ID: 2018121605 - Play ID: 1770
# (2:34) (Shotgun) D.Prescott pass incomplete deep left to N.Brown. IND-Q.Wilson was injured during the play.
# Play Error
# Game ID: 2018121605 - Play ID: 2544
# (11:23) D.Prescott pass short right to N.Brown to DAL 39 for 14 yards (M.Adams, A.Walker).
# MIA - week1
# MIA - week2
# MIA - week3
# MIA - week4
# MIA - week5
# MIA - week6
# MIA - week7
# MIA - week8
# MIA - week9
# MIA - week10
# MIA - week11
# MIA - week12
# MIA - week13
# MIA - week14
# MIA - week15
# MIA - week16
# MIA - week17
# BAL - week1
# BAL - week2
# BAL - week3
# BAL - week4
# BAL - week5
# BAL - week6
# BAL - week7
# BAL - week8
# BAL - week9
# BAL - week10
# BAL - week11
# BAL - week12
# BAL - week13
# BAL - week14
# BAL - week15
# BAL - week16
# BAL - week17
# Play Error
# Game ID: 2018092301 - Play ID: 2225
# (:37) (Shotgun) C.Keenum pass incomplete short left to C.Sutton.
# Play Error
# Game ID: 2018092301 - Play ID: 3945
# (6:16) (Shotgun) C.Keenum pass incomplete short left to D.Booker.
# Play Error
# Game ID: 2018092301 - Play ID: 4021
# (5:23) (Shotgun) C.Keenum pass short right to D.Booker to BLT 35 for 5 yards (C.Clark).
# Play Error
# CHI - week2
# CHI - week3
# CHI - week4
# CHI - week5
# CHI - week6
# CHI - week7
# CHI - week8
# CHI - week9
# CHI - week10
# CHI - week11
# CHI - week12
# CHI - week13
# CHI - week14
# CHI - week15
# CHI - week16
# CHI - week17
# HOU - week1
# HOU - week2
# HOU - week3
# HOU - week4
# HOU - week5
# HOU - week6
# HOU - week7
# HOU - week8
# HOU - week9
# HOU - week10
# HOU - week11
# HOU - week12
# HOU - week13
# HOU - week14
# HOU - week15
# HOU - week16
# HOU - week17
# Error! Whitney Mercilus has has more than one coverage type!
# KC - week1
# KC - week2
# KC - week3
# KC - week4
# KC - week5
# KC - week6
# KC - week7
# KC - week8
# KC - week9
# KC - week10
# KC - week11
# KC - week12
# KC - week13
# KC - week14
# KC - week15
# KC - week16
# KC - week17
# MIN - week1
# MIN - week2
# MIN - week3
# MIN - week4
# MIN - week5
# MIN - week6
# MIN - week7
# MIN - week8
# MIN - week9
# MIN - week10
# MIN - week11
# MIN - week12
# MIN - week13
# MIN - week14
# MIN - week15
# MIN - week16
# MIN - week17
# SEA - week1
# SEA - week2
# SEA - week3
# SEA - week4
# SEA - week5
# SEA - week6
# SEA - week7
# SEA - week8
# SEA - week9
# SEA - week10
# SEA - week11
# SEA - week12
# SEA - week13
# SEA - week14
# SEA - week15
# SEA - week16
# SEA - week17
# LAC - week1
# LAC - week2
# LAC - week3
# LAC - week4
# LAC - week5
# LAC - week6
# LAC - week7
# LAC - week8
# LAC - week9
# LAC - week10
# LAC - week11
# LAC - week12
# LAC - week13
# LAC - week14
# LAC - week15
# LAC - week16
# LAC - week17

# %%
off_production = pd.read_csv(os.path.join(basepath,'offensive production.csv'),index_col=0)

# %%
plays = analysis.return_plays(target_coverage='man')
# Out:
# (2:34) (Shotgun) D.Prescott pass incomplete deep left to N.Brown. IND-Q.Wilson was injured during the play.
# (11:23) D.Prescott pass short right to N.Brown to DAL 39 for 14 yards (M.Adams, A.Walker).
# (:37) (Shotgun) C.Keenum pass incomplete short left to C.Sutton.
# (6:16) (Shotgun) C.Keenum pass incomplete short left to D.Booker.
# (5:23) (Shotgun) C.Keenum pass short right to D.Booker to BLT 35 for 5 yards (C.Clark).
# (4:57) (No Huddle, Shotgun) C.Keenum pass short right to J.Butt ran ob at BLT 30 for 5 yards.
# (:37) (Shotgun) S.Darnold pass incomplete deep left to R.Anderson.
# (:32) (Shotgun) S.Darnold pass deep right to D.Burnett pushed ob at NYJ 36 for 25 yards (K.Crossen).
# (9:35) S.Darnold pass incomplete short right to R.Anderson (J.Jackson).
# (8:50) (Shotgun) S.Darnold pass incomplete short right to J.Leggett.

# %%
len(plays)
# Out:
# 4378

# %%
sorted_plays = sort_plays_by_result(plays)

# %%
len(sorted_plays['completed'])
# Out:
# 2492

# %%
len(sorted_plays['incompleted'])
# Out:
# 1791

# %%
len(sorted_plays['intercepted'])
# Out:
# 94

# %%
len(sorted_plays['other'])
# Out:
# 1

# %%
results = []
for play in plays:
    db = play.man_responsible_dbacks[0]
    rc = play.target
    rc_production = off_production.loc[rc.nflId]
    epa_delta = play.epa - rc_production['epa/target']
    
    res = [db.nflId, db.name, rc.nflId, rc.name, play.epa, rc_production['epa/target'], epa_delta]
    
    results.append(res)

# %%
columns = ['db nflId', 'db name','rc nflId', 'rc name', 'play epa', 'expected epa', 'epa delta']

# %%
results = pd.DataFrame(results, columns=columns)

# %%
results
# Out:
#       db nflId        db name  rc nflId           rc name  play epa  \
# 0      2552689   Ronald Darby   2495454       Julio Jones -0.551513
# 1      2557958   Sidney Jones   2533040      Mohamed Sanu -0.432498
# 2      2552689   Ronald Darby   2495454       Julio Jones  0.808959
# 3      2555383    Jalen Mills   2495454       Julio Jones  1.160936
# 4      2555383    Jalen Mills   2495454       Julio Jones -0.896250
# ...        ...            ...       ...               ...       ...
# 4373   2559164  Michael Davis   2558985       Tim Patrick -0.466679
# 4374   2532861  Casey Hayward   2560888  Courtland Sutton  1.483256
# 4375   2559164  Michael Davis   2560733     Royce Freeman  0.770422
# 4376   2559164  Michael Davis   2561002  DaeSean Hamilton  1.791403
# 4377   2559164  Michael Davis   2558985       Tim Patrick -1.217191
#
#       expected epa  epa delta
# 0            0.402  -0.953513
# 1            0.440  -0.872498
# 2            0.402   0.406959
# 3            0.402   0.758936
# 4            0.402  -1.298250
# ...            ...        ...
# 4373         0.247  -0.713679
# 4374         0.162   1.321256
# 4375        -0.189   0.959422
# 4376         0.064   1.727403
# 4377         0.247  -1.464191
#
# [4378 rows x 7 columns]

# %%
len(results['db nflId'].unique())
# Out:
# 391

# %%
totals = []

for _id in results['db nflId'].unique():
    db_df = results[results['db nflId'] == _id]
    db_name = db_df['db name'].values[0]
    
    db_epa_total = db_df['epa delta'].sum()
    db_epa_mean = db_df['epa delta'].mean()
    
    totals.append([_id,db_name, db_epa_total, db_epa_mean])

# %%
totals = pd.DataFrame(totals,columns=['id','name','total epa','mean epa'])

# %%
totals
# Out:
#           id              name  total epa  mean epa
# 0    2552689      Ronald Darby  -4.091334 -0.136378
# 1    2557958      Sidney Jones  -2.677141 -0.243376
# 2    2555383       Jalen Mills  -5.499084 -0.289425
# 3    2532800     Nigel Bradham   0.495017  0.123754
# 4      79848   Malcolm Jenkins   5.943880  0.457222
# ..       ...               ...        ...       ...
# 386  2556148     Jatavis Brown   1.275369  1.275369
# 387  2550842   Adrian Phillips  -1.451159 -1.451159
# 388  2559164     Michael Davis -20.647828 -0.573551
# 389  2560826     Uchenna Nwosu   0.120131  0.120131
# 390  2558182  Rayshawn Jenkins   1.406673  0.703337
#
# [391 rows x 4 columns]

# %%
totals.sort_values('total epa').head(10)
# Out:
#           id                 name  total epa  mean epa
# 71   2533062      Stephon Gilmore -24.995266 -0.490103
# 192  2557867    Tre'Davious White -22.726097 -0.598055
# 56   2558067      Marlon Humphrey -22.353836 -0.604158
# 388  2559164        Michael Davis -20.647828 -0.573551
# 73     89756       Jason McCourty -16.891238 -0.344719
# 45   2555539        Xavien Howard -16.500493 -0.634634
# 360  2555177  Mackensie Alexander -13.469955 -0.538798
# 307  2541162           A.J. Bouye -12.878965 -0.367970
# 329   494289     Sherrick McManis -12.780084 -1.278008
# 117  2555175      James Bradberry -12.323266 -0.373432
