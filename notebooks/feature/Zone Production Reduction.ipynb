# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import os
import glob
import sys

# %%
from utils import set_basepath

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data/notebooks/feature'

# %%
basepath = set_basepath(steps=2)

# %%
sys.path[0]
# Out:
# '/Users/jacobhow/Documents/programming-projects/nfl-big-data'

# %%
from src.team import Team
from src.game import Game
from src.play import Play
from src.player import Player
from src.analysis import Analysis, sort_plays_by_result

# %%
analysis = Analysis(basepath=basepath)

# %%
analysis.load_data()

# %%
analysis.load_weeks()

# %%
analysis.weeks.keys()
# Out:
# dict_keys(['week1', 'week2', 'week3', 'week4', 'week5', 'week6', 'week7', 'week8', 'week9', 'week10', 'week11', 'week12', 'week13', 'week14', 'week15', 'week16', 'week17'])

# %%
analysis.process_games()

# %%
analysis.process_teams()
# Out:
# PHI - week1
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from line'] = self.player_tracking['x'] - self.line_of_scrimmage
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance to sideline'] = [min((160/3) - y,y) for y in self.player_tracking['y'].values]
# /Users/jacobhow/Documents/programming-projects/nfl-big-data/src/play.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.player_tracking['distance from center'] = self.player_tracking['y'] - self.play_center
# PHI - week2
# PHI - week3
# PHI - week4
# PHI - week5
# PHI - week6
# PHI - week7
# PHI - week8
# PHI - week9
# PHI - week10
# PHI - week11
# PHI - week12
# PHI - week13
# PHI - week14
# PHI - week15
# PHI - week16
# PHI - week17
# CLE - week1
# CLE - week2
# CLE - week3
# CLE - week4
# CLE - week5
# CLE - week6
# CLE - week7
# CLE - week8
# CLE - week9
# CLE - week10
# CLE - week11
# CLE - week12
# CLE - week13
# CLE - week14
# CLE - week15
# CLE - week16
# CLE - week17
# IND - week1
# IND - week2
# IND - week3
# IND - week4
# IND - week5
# IND - week6
# IND - week7
# IND - week8
# IND - week9
# IND - week10
# IND - week11
# IND - week12
# IND - week13
# IND - week14
# IND - week15
# IND - week16
# IND - week17
# Play Error
# Game ID: 2018121605 - Play ID: 1770
# (2:34) (Shotgun) D.Prescott pass incomplete deep left to N.Brown. IND-Q.Wilson was injured during the play.
# Play Error
# Game ID: 2018121605 - Play ID: 2544
# (11:23) D.Prescott pass short right to N.Brown to DAL 39 for 14 yards (M.Adams, A.Walker).
# MIA - week1
# MIA - week2
# MIA - week3
# MIA - week4
# MIA - week5
# MIA - week6
# MIA - week7
# MIA - week8
# MIA - week9
# MIA - week10
# MIA - week11
# MIA - week12
# MIA - week13
# MIA - week14
# MIA - week15
# MIA - week16
# MIA - week17
# BAL - week1
# BAL - week2
# BAL - week3
# BAL - week4
# BAL - week5
# BAL - week6
# BAL - week7
# BAL - week8
# BAL - week9
# BAL - week10
# BAL - week11
# BAL - week12
# BAL - week13
# BAL - week14
# BAL - week15
# BAL - week16
# BAL - week17
# Play Error
# Game ID: 2018092301 - Play ID: 2225
# (:37) (Shotgun) C.Keenum pass incomplete short left to C.Sutton.
# Play Error
# Game ID: 2018092301 - Play ID: 3945
# (6:16) (Shotgun) C.Keenum pass incomplete short left to D.Booker.
# Play Error
# Game ID: 2018092301 - Play ID: 4021
# (5:23) (Shotgun) C.Keenum pass short right to D.Booker to BLT 35 for 5 yards (C.Clark).
# Play Error
# Game ID: 2018092301 - Play ID: 4045
# JAX - week15
# JAX - week16
# JAX - week17
# DAL - week1
# DAL - week2
# DAL - week3
# DAL - week4
# DAL - week5
# DAL - week6
# DAL - week7
# DAL - week8
# DAL - week9
# DAL - week10
# DAL - week11
# DAL - week12
# DAL - week13
# DAL - week14
# DAL - week15
# DAL - week16
# DAL - week17
# CHI - week1
# CHI - week2
# CHI - week3
# CHI - week4
# CHI - week5
# CHI - week6
# CHI - week7
# CHI - week8
# CHI - week9
# CHI - week10
# CHI - week11
# CHI - week12
# CHI - week13
# CHI - week14
# CHI - week15
# CHI - week16
# CHI - week17
# HOU - week1
# HOU - week2
# HOU - week3
# HOU - week4
# HOU - week5
# HOU - week6
# HOU - week7
# HOU - week8
# HOU - week9
# HOU - week10
# HOU - week11
# HOU - week12
# HOU - week13
# HOU - week14
# HOU - week15
# HOU - week16
# HOU - week17
# Error! Whitney Mercilus has has more than one coverage type!
# KC - week1
# KC - week2
# KC - week3
# KC - week4
# KC - week5
# KC - week6
# KC - week7
# KC - week8
# KC - week9
# KC - week10
# KC - week11
# KC - week12
# KC - week13
# KC - week14
# KC - week15
# KC - week16
# KC - week17
# MIN - week1
# MIN - week2
# MIN - week3
# MIN - week4
# MIN - week5
# MIN - week6
# MIN - week7
# MIN - week8
# MIN - week9
# MIN - week10
# MIN - week11
# MIN - week12
# MIN - week13
# MIN - week14
# MIN - week15
# MIN - week16
# MIN - week17
# SEA - week1
# SEA - week2
# SEA - week3
# SEA - week4
# SEA - week5
# SEA - week6
# SEA - week7
# SEA - week8
# SEA - week9
# SEA - week10
# SEA - week11
# SEA - week12
# SEA - week13
# SEA - week14
# SEA - week15
# SEA - week16
# SEA - week17
# LAC - week1
# LAC - week2
# LAC - week3
# LAC - week4
# LAC - week5
# LAC - week6
# LAC - week7
# LAC - week8
# LAC - week9
# LAC - week10
# LAC - week11
# LAC - week12
# LAC - week13
# LAC - week14
# LAC - week15
# LAC - week16
# LAC - week17

# %%
off_production = pd.read_csv(os.path.join(basepath,'offensive production.csv'),index_col=0)

# %%
plays = analysis.return_plays(target_coverage='zone')
# Out:
# (2:34) (Shotgun) D.Prescott pass incomplete deep left to N.Brown. IND-Q.Wilson was injured during the play.
# (11:23) D.Prescott pass short right to N.Brown to DAL 39 for 14 yards (M.Adams, A.Walker).
# (:37) (Shotgun) C.Keenum pass incomplete short left to C.Sutton.
# (6:16) (Shotgun) C.Keenum pass incomplete short left to D.Booker.
# (5:23) (Shotgun) C.Keenum pass short right to D.Booker to BLT 35 for 5 yards (C.Clark).
# (4:57) (No Huddle, Shotgun) C.Keenum pass short right to J.Butt ran ob at BLT 30 for 5 yards.
# (:37) (Shotgun) S.Darnold pass incomplete deep left to R.Anderson.
# (:32) (Shotgun) S.Darnold pass deep right to D.Burnett pushed ob at NYJ 36 for 25 yards (K.Crossen).
# (9:35) S.Darnold pass incomplete short right to R.Anderson (J.Jackson).
# (8:50) (Shotgun) S.Darnold pass incomplete short right to J.Leggett.

# %%
len(plays)
# Out:
# 4787

# %%
sorted_plays = sort_plays_by_result(plays)

# %%
len(sorted_plays['completed'])
# Out:
# 2775

# %%
len(sorted_plays['incompleted'])
# Out:
# 1839

# %%
len(sorted_plays['intercepted'])
# Out:
# 173

# %%
len(sorted_plays['other'])
# Out:
# 0

# %%
results = []
for play in plays:
    
    if len(play.zone_responsible_dbacks) > 1:
        print('Double Coverage')
        continue
        
    db = play.zone_responsible_dbacks[0]
    rc = play.target
    rc_production = off_production.loc[rc.nflId]
    epa_delta = play.epa - rc_production['epa/target']
    
    res = [db.nflId, db.name, rc.nflId, rc.name, play.epa, rc_production['epa/target'], epa_delta]
    
    results.append(res)

# %%
columns = ['db nflId', 'db name','rc nflId', 'rc name', 'play epa', 'expected epa', 'epa delta']

# %%
results = pd.DataFrame(results, columns=columns)

# %%
results
# Out:
#       db nflId          db name  rc nflId           rc name  play epa  \
# 0      2555383      Jalen Mills   2495454       Julio Jones  0.261827
# 1        79848  Malcolm Jenkins   2560854     Calvin Ridley -0.372360
# 2        79848  Malcolm Jenkins   2495454       Julio Jones  3.047530
# 3      2558175       Nate Gerry   2543583   Devonta Freeman -0.842272
# 4      2552689     Ronald Darby   2533040      Mohamed Sanu -0.429863
# ...        ...              ...       ...               ...       ...
# 4782   2550842  Adrian Phillips   2555223   Devontae Booker  0.040901
# 4783   2559164    Michael Davis   2561002  DaeSean Hamilton  0.408445
# 4784   2550842  Adrian Phillips   2560733     Royce Freeman -0.436124
# 4785   2557927     Desmond King   2561002  DaeSean Hamilton -0.915667
# 4786   2557927     Desmond King   2559485    River Cracraft -3.412723
#
#       expected epa  epa delta
# 0            0.402  -0.140173
# 1            0.483  -0.855360
# 2            0.402   2.645530
# 3           -0.746  -0.096272
# 4            0.440  -0.869863
# ...            ...        ...
# 4782        -0.027   0.067901
# 4783         0.064   0.344445
# 4784        -0.189  -0.247124
# 4785         0.064  -0.979667
# 4786        -0.418  -2.994723
#
# [4787 rows x 7 columns]

# %%
results.sort_values('play epa')
# Out:
#       db nflId           db name  rc nflId          rc name   play epa  \
# 4610   2532966      Bobby Wagner   2560938      Jeff Wilson -11.935951
# 4674   2557927      Desmond King      2346    Pierre Garcon -10.175076
# 3995   2558176     Eddie Jackson   2558049  Michael Roberts  -9.084004
# 4389   2543592  Anthony Hitchens      1032     Jordy Nelson  -8.887855
# 3306   2552488     Marcus Peters     71265       Jared Cook  -8.816359
# ...        ...               ...       ...              ...        ...
# 3894   2558176     Eddie Jackson   2495448     Randall Cobb   6.477970
# 3585    494307    Darian Stewart   2558266    George Kittle   6.649251
# 766      89756    Jason McCourty   2557917      Kareem Hunt   6.730304
# 1747   2561527         Mike Ford   2560813       D.J. Moore   7.098656
# 1154    494261      Kurt Coleman   2552622   Chris Manhertz   7.335755
#
#       expected epa  epa delta
# 4610        -0.510 -11.425951
# 4674        -0.095 -10.080076
# 3995        -0.535  -8.549004
# 4389         0.176  -9.063855
# 3306         0.227  -9.043359
# ...            ...        ...
# 3894         0.084   6.393970
# 3585         0.440   6.209251
# 766          0.883   5.847304
# 1747         0.045   7.053656
# 1154        -0.090   7.425755
#
# [4787 rows x 7 columns]

# %%
len(results['db nflId'].unique())
# Out:
# 453

# %%
totals = []

for _id in results['db nflId'].unique():
    db_df = results[results['db nflId'] == _id]
    db_name = db_df['db name'].values[0]
    
    nPlays = db_df.shape[0]
    
    db_epa_total = db_df['epa delta'].sum()
    db_epa_mean = db_df['epa delta'].mean()
        
    totals.append([_id,db_name, nPlays, db_epa_total, db_epa_mean])

# %%
totals = pd.DataFrame(totals,columns=['id','name','zone coverage count','total epa','mean epa'])

# %%
totals
# Out:
#           id              name  zone coverage count  total epa  mean epa
# 0    2555383       Jalen Mills                   19  12.511691  0.658510
# 1      79848   Malcolm Jenkins                   25  -7.750022 -0.310001
# 2    2558175        Nate Gerry                    2  -5.125558 -2.562779
# 3    2552689      Ronald Darby                   24  -5.261468 -0.219228
# 4    2534832     Rodney McLeod                    3   1.728145  0.576048
# ..       ...               ...                  ...        ...       ...
# 448  2559164     Michael Davis                    8   5.840343  0.730043
# 449  2552310   Denzel Perryman                    2  -0.969345 -0.484673
# 450  2558182  Rayshawn Jenkins                    3  -3.028279 -1.009426
# 451  2552296      Kyle Emanuel                    1   1.082574  1.082574
# 452  2552313     Hayes Pullard                    1   1.754608  1.754608
#
# [453 rows x 5 columns]

# %%
totals.sort_values('total epa').head(10)
# Out:
#           id              name  zone coverage count  total epa  mean epa
# 125  2555175   James Bradberry                   51 -28.367857 -0.556232
# 373  2543681       Kyle Fuller                   31 -27.847193 -0.898297
# 441  2557927      Desmond King                   27 -25.127460 -0.930647
# 384  2495872  Johnathan Joseph                   41 -23.808774 -0.580702
# 35   2543811      Pierre Desir                   17 -18.087348 -1.063962
# 295  2555552        Ryan Smith                   15 -18.069314 -1.204621
# 346  2543711      Telvin Smith                   12 -17.203150 -1.433596
# 57   2558067   Marlon Humphrey                   17 -14.716760 -0.865692
# 359  2555531     Anthony Brown                   21 -14.533275 -0.692061
# 265  2495281      Mason Foster                   15 -14.340529 -0.956035

# %%
totals.sort_values('total epa').tail(10)
# Out:
#           id             name  zone coverage count  total epa  mean epa
# 305  2495507  Richard Sherman                   14  12.430706  0.887908
# 0    2555383      Jalen Mills                   19  12.511691  0.658510
# 33   2558976   Kenny Moore II                   20  13.267082  0.663354
# 387  2560851      Justin Reid                   20  13.272943  0.663647
# 361  2557840   Chidobe Awuzie                   18  13.670320  0.759462
# 391  2495251  Shareece Wright                   21  14.431564  0.687217
# 188  2539233   Shawn Williams                   23  17.094911  0.743257
# 127  2505708       Mike Adams                   20  17.318202  0.865910
# 111  2539932     Jamar Taylor                   14  18.447342  1.317667
# 99   2556735      Ken Crawley                   12  20.707958  1.725663
